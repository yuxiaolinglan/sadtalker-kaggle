# %%
# !git clone https://github.com/yuxiaolinglan/sadtalker-kaggle
# %cd sadtalker-kaggle
# !pip install fvcore
# !pip install --no-index --no-cache-dir pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py310_cu113_pyt1121/download.html
# !pip install git+https://github.com/TencentARC/GFPGAN
# !pip install trimesh

# %%
# !pip install git+https://github.com/xinntao/Real-ESRGAN

# %% [markdown]
# # 模型下载

# %%
# %cd /kaggle/working/sadtalker-kaggle
# %mkdir /kaggle/working/sadtalker-kaggle/checkpoints
#### download the new links.
# !wget -nc https://github.com/OpenTalker/SadTalker/releases/download/v0.0.2-rc/mapping_00109-model.pth.tar -O  ./checkpoints/mapping_00109-model.pth.tar
# !wget -nc https://github.com/OpenTalker/SadTalker/releases/download/v0.0.2-rc/mapping_00229-model.pth.tar -O  ./checkpoints/mapping_00229-model.pth.tar
# !wget -nc https://github.com/OpenTalker/SadTalker/releases/download/v0.0.2-rc/SadTalker_V0.0.2_256.safetensors -O  ./checkpoints/SadTalker_V0.0.2_256.safetensors
# !wget -nc https://github.com/OpenTalker/SadTalker/releases/download/v0.0.2-rc/SadTalker_V0.0.2_512.safetensors -O  ./checkpoints/SadTalker_V0.0.2_512.safetensors
 
 
### enhancer 
# !mkdir -p ./gfpgan/weights
# !wget -nc https://github.com/xinntao/facexlib/releases/download/v0.1.0/alignment_WFLW_4HG.pth -O ./gfpgan/weights/alignment_WFLW_4HG.pth 
# !wget -nc https://github.com/xinntao/facexlib/releases/download/v0.1.0/detection_Resnet50_Final.pth -O ./gfpgan/weights/detection_Resnet50_Final.pth 
# !wget -nc https://github.com/TencentARC/GFPGAN/releases/download/v1.3.4/RestoreFormer.pth -O ./gfpgan/weights/RestoreFormer.pth 
# !wget -nc https://github.com/TencentARC/GFPGAN/releases/download/v0.1.0/GFPGANv1.pth -O ./gfpgan/weights/GFPGANv1.pth 
# !wget -nc https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.4.pth -O ./gfpgan/weights/GFPGANv1.4.pth 
# !wget -nc https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.3.pth -O ./gfpgan/weights/GFPGANv1.3.pth 
# !wget -nc https://github.com/TencentARC/GFPGAN/releases/download/v0.2.0/GFPGANCleanv1-NoCE-C2.pth -O ./gfpgan/weights/GFPGANv1.2.pth 
# !wget -nc https://github.com/xinntao/facexlib/releases/download/v0.2.2/parsing_parsenet.pth -O ./gfpgan/weights/parsing_parsenet.pth 
# !wget -nc https://github.com/Winfredy/SadTalker/releases/download/v0.0.2/BFM_Fitting.zip -O ./checkpoints/BFM_Fitting.zip
# !unzip -n ./checkpoints/BFM_Fitting.zip -d ./checkpoints/

# %% [markdown]
# # 简单的sadtalker页面<br>
# 如果出现numpy=1.17的bug，把venv清掉重开，没有bug就不要运行这条命令

# %%
# !rm -rf /kaggle/working/sadtalker-kaggle/venv

# %% [markdown]
# - 页面增加参数介绍（来自原文档的inference和调试过程中的理解）
# - face enhancer : 可以选择 gfphan1.4, gfpgan 1.3 gfpgan1.2等， 并设置up_scale(放大的数值)
# - input_yaw_list等三个参数， 输入范例（数字之间留一个空格）：
#   -1 0 1 2 0 -1
# - the batch size of facerender : 表情幅度大小

# %%
# 开启推理页面
# %cd /kaggle/working/sadtalker-kaggle
# !npm install -g localtunnel
import subprocess
import threading
import time
import socket
import urllib.request
def iframe_thread(port):
    while True:
        time.sleep(0.5)
        sock= socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        if result == 0:
            break
        sock.close()

        from colorama import Fore, Style
    print (Fore.GREEN + "\nIP: ", Fore. RED, urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"), "\n", Style. RESET_ALL)
    p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
    for line in p.stdout:
        print(line.decode(), end='')
threading.Thread (target=iframe_thread, daemon=True, args=(9874,)).start()

# !bash webui.sh

# %% [markdown]
# # 文件删除区

# %%
# !rm -rf /kaggle/working/SadTalker/results

# %% [markdown]
# # 图像修复

# %%
! git clone https://github.com/TencentARC/GFPGAN

# %%
# 修一遍和修两遍效果有啥区别
# %cd /kaggle/working/SadTalker/GFPGAN
# !python inference_gfpgan.py -i /kaggle/input/photos2/kanghui2.png -o /kaggle/working/img_png/output -v 1.2 -s 2
# !python inference_gfpgan.py -i /kaggle/working/GFPGAN/output/restored_imgs/qiyue2.png -o ./output -v 1.3 -s 2
# !python inference_gfpgan.py -i /kaggle/working/GFPGAN/output/restored_imgs/zhang4.png -o ./output -v 1.3 -s 2
